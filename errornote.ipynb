# %% [markdown]
# # 에러노트
#
# 작업중 발생한 에러, 발생상황, 해결법 작성

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# - 이미 한 번 정상작동한 코드를 재실행했는데 오류가 발생함.
# - 찾아보니 이미지 파일의 path가 잘못되었다는 오류. 파일을 새로 열면서 구글드라이브 마운트 하지않아 경로가 달라진듯.
# - 경로 수정하니 정상작동함

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - selectROI 로 영역을 지정하여 좌표를 받아오려 했으나 새로 활성화된 창이 죽어버림.
# - cv2.imshow() 는 창이름도 지정해줘야함
# - colab의 cv2_imshow와 다름
