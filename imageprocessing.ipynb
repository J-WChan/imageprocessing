# %%
import matplotlib.pyplot as plt
import sklearn as sk
import tensorflow as tf
import pandas as pd
import numpy as np
import keras 
import scipy
import sympy
import datetime
import cv2

# %%
img = cv2.imread('./CJE_2023_Lecture_Test_ImageProcessing/Image_Processing/lena.jpg')

# %%
x,y,w,h = cv2.selectROI(img=img)

# %%
img = img[y:y+h, x:x+w]

# %%
plt.imshow(img)

# %%
now = datetime.datetime.now()

# %%
now_str = now.strftime("%Y%m%d%H%M%S%f")

# %%
now_str
# Out:
# '20230420162029854802'

# %%
cv2.imshow('test',img)

# %%
cv2.imwrite(f'./CJE_2023_Lecture_Test_ImageProcessing/output/{now_str}.jpg',img)
# Out:
# True
